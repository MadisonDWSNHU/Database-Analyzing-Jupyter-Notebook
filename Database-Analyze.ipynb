# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility

# network and training
# NB_EPOCH = 200
# NB_EPOCH = 20
# Below is my changed parameter and the original
# NB_EPOCH = 250
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10  
OPTIMIZER = SGD()  
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2  # How much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets

(X_train, y_train), (X_test, y_test) = mnist.load_data()
RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices 

Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# First parameter change
BATCH_SIZE = 45

# Code changed to accomodate parameter change
history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score for BATCH_SIZE=45:", score[0])
print('Test accuracy for BATCH_SIZE=45:', score[1])

# Second parameter change
NB_EPOCH = 40

# Change code to accomodate parameter change
history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score for NB_EPOCH=40:", score[0])
print('Test accuracy for NB_EPOCH=40:', score[1])

# Final parameter change
N_HIDDEN = 142

model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                    verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score for N_HIDDEN=142:", score[0])
print('Test accuracy for N_HIDDEN=142:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 4s 75us/step - loss: 1.3737 - accuracy: 0.6710 - val_loss: 0.6838 - val_accuracy: 0.8516
# Epoch 2/20
# 48000/48000 [==============================] - 3s 59us/step - loss: 0.5670 - accuracy: 0.8574 - val_loss: 0.4377 - val_accuracy: 0.8860
# Epoch 3/20
# 48000/48000 [==============================] - 3s 61us/step - loss: 0.4302 - accuracy: 0.8827 - val_loss: 0.3670 - val_accuracy: 0.9002
# Epoch 4/20
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3752 - accuracy: 0.8952 - val_loss: 0.3331 - val_accuracy: 0.9072
# Epoch 5/20
# 48000/48000 [==============================] - 3s 69us/step - loss: 0.3435 - accuracy: 0.9026 - val_loss: 0.3100 - val_accuracy: 0.9137
# Epoch 6/20
# 48000/48000 [==============================] - 3s 70us/step - loss: 0.3217 - accuracy: 0.9082 - val_loss: 0.2941 - val_accuracy: 0.9169
# Epoch 7/20
# 48000/48000 [==============================] - 3s 71us/step - loss: 0.3045 - accuracy: 0.9133 - val_loss: 0.2795 - val_accuracy: 0.9213
# Epoch 8/20
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2901 - accuracy: 0.9179 - val_loss: 0.2682 - val_accuracy: 0.9257
# Epoch 9/20
# 48000/48000 [==============================] - 3s 65us/step - loss: 0
# 48000/48000 [==============================] - 8s 157us/step - loss: 0.2019 - accuracy: 0.9425 - val_loss: 0.1945 - val_accuracy: 0.9477
# Epoch 8/40
# 48000/48000 [==============================] - 8s 160us/step - loss: 0.1871 - accuracy: 0.9464 - val_loss: 0.1816 - val_accuracy: 0.9502
# Epoch 9/40
# 48000/48000 [==============================] - 9s 190us/step - loss: 0.1741 - accuracy: 0.9504 - val_loss: 0.1702 - val_accuracy: 0.9545
# Epoch 10/40
# 48000/48000 [==============================] - 8s 158us/step - loss: 0.1626 - accuracy: 0.9540 - val_loss: 0.1647 - val_accuracy: 0.9551
# Epoch 11/40
# 48000/48000 [==============================] - 9s 183us/step - loss: 0.1520 - accuracy: 0.9568 - val_loss: 0.1566 - val_accuracy: 0.9565
# Epoch 12/40
# 48000/48000 [==============================] - 8s 165us/step - loss: 0.1432 - accuracy: 0.9595 - val_loss: 0.1518 - val_accuracy: 0.9583
# Epoch 13/40
# 48000/48000 [==============================] - 7s 140us/step - loss: 0.1353 - accuracy: 0.9621 - val_loss: 0.1427 - val_accuracy: 0.9611
# Epoch 14/40
# 48000/48000 [==============================] - 7s 145us/step - loss: 0.1276 - accuracy: 0.9631 - val_loss: 0.1385 - val_accuracy: 0.9615
# Epoch 15/40
# 48000/48000 [==============================] - 8s 168us/step - loss: 0.1211 - accuracy: 0.9661 - val_loss: 0.1350 - val_accuracy: 0.9628
# Epoch 16/40
# 48000/48000 [==============================] - 8s 176us/step - loss: 0.1149 - accuracy: 0.9678 - val_loss: 0.1284 - val_accuracy: 0.9651
# Epoch 17/40
# 48000/48000 [==============================] - 9s 192us/step - loss: 0.1096 - accuracy: 0.9691 - val_loss: 0.1244 - val_accuracy: 0.9655
# Epoch 18/40
# 48000/48000 [==============================] - 8s 174us/step - loss: 0.1041 - accuracy: 0.9702 - val_loss: 0.1232 - val_accuracy: 0.9661
# Epoch 19/40
# 48000/48000 [==============================] - 6s 129us/step - loss: 0.0995 - accuracy: 0.9720 - val_loss: 0.1210 - val_accuracy: 0.9666
# Epoch 20/40
# 48000/48000 [==============================] - 6s 124us/step - loss: 0.0948 - accuracy: 0.9730 - val_loss: 0.1172 - val_accuracy: 0.9675
# Epoch 21/40
# 48000/48000 [==============================] - 7s 136us/step - loss: 0.0904 - accuracy: 0.9753 - val_loss: 0.1141 - val_accuracy: 0.9680
# Epoch 22/40
# 48000/48000 [==============================] - 6s 134us/step - loss: 0.0867 - accuracy: 0.9759 - val_loss: 0.1111 - val_accuracy: 0.9688
# Epoch 23/40
# 48000/48000 [==============================] - 7s 152us/step - loss: 0.0830 - accuracy: 0.9770 - val_loss: 0.1098 - val_accuracy: 0.9695
# Epoch 24/40
# 48000/48000 [==============================] - 7s 138us/step - loss: 0.0795 - accuracy: 0.9781 - val_loss: 0.1097 - val_accuracy: 0.9687
# Epoch 25/40
# 48000/48000 [==============================] - 6s 130us/step - loss: 0.0759 - accuracy: 0.9789 - val_loss: 0.1058 - val_accuracy: 0.9693
# Epoch 26/40
# 48000/48000 [==============================] - 7s 147us/step - loss: 0.0731 - accuracy: 0.9799 - val_loss: 0.1035 - val_accuracy: 0.9710
# Epoch 27/40
# 48000/48000 [==============================] - 7s 146us/step - loss: 0.0702 - accuracy: 0.9810 - val_loss: 0.1028 - val_accuracy: 0.9711
# Epoch 28/40
# 48000/48000 [==============================] - 7s 138us/step - loss: 0.0673 - accuracy: 0.9818 - val_loss: 0.1012 - val_accuracy: 0.9712
# Epoch 29/40
# 48000/48000 [==============================] - 6s 127us/step - loss: 0.0649 - accuracy: 0.9826 - val_loss: 0.0988 - val_accuracy: 0.9718
# Epoch 30/40
# 48000/48000 [==============================] - 7s 139us/step - loss: 0.0623 - accuracy: 0.9835 - val_loss: 0.0983 - val_accuracy: 0.9718
# Epoch 31/40
# 48000/48000 [==============================] - 7s 143us/step - loss: 0.0598 - accuracy: 0.9837 - val_loss: 0.0978 - val_accuracy: 0.9717
# Epoch 32/40
# 48000/48000 [==============================] - 7s 151us/step - loss: 0.0577 - accuracy: 0.9846 - val_loss: 0.0981 - val_accuracy: 0.9716
# Epoch 33/40
# 48000/48000 [==============================] - 7s 148us/step - loss: 0.0553 - accuracy: 0.9854 - val_loss: 0.0959 - val_accuracy: 0.9725
# Epoch 34/40
# 48000/48000 [==============================] - 7s 148us/step - loss: 0.0534 - accuracy: 0.9864 - val_loss: 0.0949 - val_accuracy: 0.9731
# Epoch 35/40
# 48000/48000 [==============================] - 7s 145us/step - loss: 0.0515 - accuracy: 0.9868 - val_loss: 0.0952 - val_accuracy: 0.9728
# Epoch 36/40
# 48000/48000 [==============================] - 7s 148us/step - loss: 0.0499 - accuracy: 0.9875 - val_loss: 0.0933 - val_accuracy: 0.9730
# Epoch 37/40
# 48000/48000 [==============================] - 7s 137us/step - loss: 0.0478 - accuracy: 0.9879 - val_loss: 0.0932 - val_accuracy: 0.9726
# Epoch 38/40
# 48000/48000 [==============================] - 6s 134us/step - loss: 0.0462 - accuracy: 0.9884 - val_loss: 0.0911 - val_accuracy: 0.9740
# Epoch 39/40
# 48000/48000 [==============================] - 7s 140us/step - loss: 0.0444 - accuracy: 0.9890 - val_loss: 0.0912 - val_accuracy: 0.9734
# Epoch 40/40
# 48000/48000 [==============================] - 9s 184us/step - loss: 0.0429 - accuracy: 0.9892 - val_loss: 0.0907 - val_accuracy: 0.9731
# 10000/10000 [==============================] - 0s 49us/step
# Test score for N_HIDDEN=142: 0.0799838061877992
# Test accuracy for N_HIDDEN=142: 0.9750000238418579

# %%
# Without changing any parameters from the original code, we have a baseline accuracy of around 90%
# Following the texbook and adding improvements to the code shown on pages 22 and 23, we get a better accuracy of almost 95%
# Now we have improved the code further as shown on page 25, the accuracy on training is around 90%, around 95% validation, and around 95% on the test. 
# Testing my own parameters,we get train score for batch size: 0.105, test accuracy almost 97%. The test accuracy became its highest yet, but the score the lowest for batch size. 
# The lower the batch_size, the higher the accuracy, but the lower the score. 
# For the epoch change: test score is 0.082 and accuracy is almost 98%, which is another improvement on accuracy but disprovement on score. 
# For the final parameter n_hidden is score 0.079 and accuracy 0.98. 
# The common occurence here is that as the variables get lower the accuracy gets higher and the score gets lower.
